# %%
import pandas as pd
import os

# %%
os.chdir("/cluster/home/zeyu/Projects/Program/cross_species_integration/Matching/Methods/HM_O2O/pancreatic_islet_cells")
human_mice=pd.read_csv("/cluster/home/zeyu/Projects/Program/cross_species_integration/Matching/Methods/HM_O2O/cross_species_homologue_genes/o2oResults/human_mice_o2o.csv", header=0, dtype=str)
mice_pig=pd.read_csv("/cluster/home/zeyu/Projects/Program/cross_species_integration/Matching/Methods/HM_O2O/cross_species_homologue_genes/o2oResults/mice_pig_o2o.csv", header=0, dtype=str)

# %%
print(human_mice.shape)
print(human_mice.iloc[0:5,:])
# Out:
# (18352, 2)
#   human gene name mice gene name
# 0            TUBB          Tubb5
# 1           PSMC1          Psmc1
# 2           UBE2N          Ube2n
# 3            ISL1           Isl1
# 4           SNU13          Snu13

# %%
print(mice_pig.shape)
print(mice_pig.iloc[0:5,:])
# Out:
# (15645, 2)
#   mice gene name pig gene name
# 0          Rps23         RPS23
# 1          U2af1         U2AF1
# 2         H2ac19        H2AC19
# 3         Zfp706        ZNF706
# 4         Eif2s1        EIF2S1

# %%
human_mice = human_mice.dropna(subset=[human_mice.columns[0], human_mice.columns[1]])#human_mice mice_pig
mice_pig = mice_pig.dropna(subset=[mice_pig.columns[0], mice_pig.columns[1]])
print(human_mice.shape)
print(mice_pig.shape)
# Out:
# (18352, 2)
# (15645, 2)

# %%
print(human_mice.iloc[0:5,:])
print(mice_pig.iloc[0:5,:])
# Out:
#   human gene name mice gene name
# 0            TUBB          Tubb5
# 1           PSMC1          Psmc1
# 2           UBE2N          Ube2n
# 3            ISL1           Isl1
# 4           SNU13          Snu13
#   mice gene name pig gene name
# 0          Rps23         RPS23
# 1          U2af1         U2AF1
# 2         H2ac19        H2AC19
# 3         Zfp706        ZNF706
# 4         Eif2s1        EIF2S1

# %%
human_mice=human_mice.rename(columns={human_mice.columns[0]:"human gene name"})
human_mice=human_mice.rename(columns={human_mice.columns[1]:"mice gene name"})
mice_pig=mice_pig.rename(columns={mice_pig.columns[0]:"mice gene name"})
mice_pig=mice_pig.rename(columns={mice_pig.columns[1]:"pig gene name"})

# %%
print(human_mice.shape)
print(mice_pig.shape)
# Out:
# (18352, 2)
# (15645, 2)

# %%
human_mice = human_mice.drop_duplicates()
mice_pig=mice_pig.drop_duplicates()

# %%
human_mice_pig = human_mice.merge(mice_pig, on="mice gene name", how="outer")
human_mice_pig = human_mice_pig.dropna()
print(human_mice_pig.shape)
print(human_mice_pig.iloc[0:5,:])
# Out:
# (15500, 3)
#   human gene name mice gene name pig gene name
# 0        C17orf49  0610010K14Rik      C17orf49
# 1         C2orf68  0610030E20Rik       C2orf68
# 2         C4orf19  0610040J01Rik       C4orf19
# 3         C4orf54  1110002E22Rik       C4orf54
# 4        C11orf58  1110004F10Rik      C11orf58

# %%
human_mice_pig.to_csv("human_mice_pig.csv",index=False)
