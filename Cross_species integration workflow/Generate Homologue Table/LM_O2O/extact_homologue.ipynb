# %%
import pandas as pd
import os

# %%
os.chdir("/cluster/home/zeyu/Projects/Program/cross_species_integration/Matching/Methods/LM_O2O_o2o/pancreatic_islet_cells")
human_mice=pd.read_csv("/cluster/home/zeyu/Projects/Program/cross_species_integration/Matching/Methods/LM_O2O/initial/ONNResults/human_mice_LM_O2O.csv", header=0, dtype=str,usecols=[0,1])
mice_pig=pd.read_csv("/cluster/home/zeyu/Projects/Program/cross_species_integration/Matching/Methods/LM_O2O/initial/ONNResults/mice_pig_LM_O2O.csv", header=0, dtype=str,usecols=[0,1])

# %%
print(human_mice.shape)
print(human_mice.iloc[0:5,:])
# Out:
# (16119, 2)
#   Human gene name Mouse gene name
# 0        IGHD7-27         Ighd4-1
# 1          UBE2R2          Ube2r2
# 2          TWIST2          Twist2
# 3          TUBA3D          Tuba3a
# 4          CTXND1          Gm2115

# %%
print(mice_pig.shape)
print(mice_pig.iloc[0:5,:])
# Out:
# (14390, 2)
#   mice gene name pig gene name
# 0         Dynll1        DYNLL1
# 1        Mab21l2       MAB21L2
# 2         Ube2r2        UBE2R2
# 3          Rps17         RPS17
# 4         Twist2        TWIST2

# %%
human_mice = human_mice.dropna(subset=[human_mice.columns[0], human_mice.columns[1]])#human_mice mice_pig
mice_pig = mice_pig.dropna(subset=[mice_pig.columns[0], mice_pig.columns[1]])
print(human_mice.shape)
print(mice_pig.shape)
# Out:
# (16119, 2)
# (14390, 2)

# %%
print(human_mice.iloc[0:5,:])
print(mice_pig.iloc[0:5,:])
# Out:
#   Human gene name Mouse gene name
# 0        IGHD7-27         Ighd4-1
# 1          UBE2R2          Ube2r2
# 2          TWIST2          Twist2
# 3          TUBA3D          Tuba3a
# 4          CTXND1          Gm2115
#   mice gene name pig gene name
# 0         Dynll1        DYNLL1
# 1        Mab21l2       MAB21L2
# 2         Ube2r2        UBE2R2
# 3          Rps17         RPS17
# 4         Twist2        TWIST2

# %%
human_mice=human_mice.rename(columns={human_mice.columns[0]:"human gene name"})
human_mice=human_mice.rename(columns={human_mice.columns[1]:"mice gene name"})
mice_pig=mice_pig.rename(columns={mice_pig.columns[0]:"mice gene name"})
mice_pig=mice_pig.rename(columns={mice_pig.columns[1]:"pig gene name"})

# %%
print(human_mice.shape)
print(mice_pig.shape)
# Out:
# (16119, 2)
# (14390, 2)

# %%
human_mice = human_mice.drop_duplicates()
mice_pig=mice_pig.drop_duplicates()

# %%
human_mice_pig = human_mice.merge(mice_pig, on="mice gene name", how="outer")
human_mice_pig = human_mice_pig.dropna()
print(human_mice_pig.shape)
print(human_mice_pig.iloc[0:5,:])
# Out:
# (12823, 3)
#   human gene name mice gene name pig gene name
# 1        C17orf49  0610010K14Rik      C17orf49
# 2        NCBP2AS2  0610012G03Rik      NCBP2AS2
# 3         C2orf68  0610030E20Rik       C2orf68
# 4         C4orf19  0610040J01Rik       C4orf19
# 5         C4orf54  1110002E22Rik       C4orf54

# %%
human_mice_pig.to_csv("human_mice_pig.csv",index=False)
